# %% [markdown]
# <a href="https://colab.research.google.com/github/gurramsantosh236/PythonPractice/blob/main/CreateModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('santosh')
# Out:
# santosh
