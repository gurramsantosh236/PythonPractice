# %%
print("Hello World")
# Out:
# Hello World

# %%
lst=[1,2,3,4,5]
print(lst[-3])
# Out:
# 3

# %%
x=3/1
data=type(x)
print(data)
print(x)
# Out:
# <class 'float'>
# 3.0

# %%
a=[[]] * 3
a[0].append(1)
print(a)
# Out:
# [[1], [1], [1]]

# %%
import numpy as np

a=[1,2]
b=[3,4]
c=np.array(a)
d=np.array(b)
print(a+b)
print(c+d)
x=[a+b for a,b in zip(a,b)]
print(x)
def sum_num(m,n):
  return( m+n)
print(list(map(sum_num,a,b)))
# Out:
# [1, 2, 3, 4]
# [4 6]
# [4, 6]
# [4, 6]

# %%
print(True//2,False//2)
# Out:
# 0 0

# %%
s="python"

print('P'+s)
# Out:
# Ppython

# %%
n=[4,2,5,1,3]
n.reverse()
m=sorted(n,reverse=True)
print(n)
print(m)
# Out:
# [3, 1, 5, 2, 4]
# [5, 4, 3, 2, 1]
