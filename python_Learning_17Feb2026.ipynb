# %%
print("Hello World")
# Out:
# Hello World

# %%
x = int(input('Enter an integer:'))
if x <= 7 and x >= 4:
 print('OK!')
elif x <= 7 and x>0:
 print('Yes')
elif x >= 4:
 print('No')
else:
 print('why?')
# Out:
# Enter an integer:-1
# why?

# %%
x=int(input('Enter a number'))
y=int(input('Enter a number'))
z=int(input('Enter a number'))
w=int(input('Enter a number'))

# Find 1st small number a from w,x,y,z
if x<=y:
  a=x
  b=y
else:
  a=y
  b=x
if a<=z:
  c=z
else:
  c=a
  a=z
if a<=w:
  d=w
else:
  d=a
  a=w

# Find 2nd small number m from b,c,d
if b<=c:
  m=b
  n=c
else:
  m=c
  n=b
if m<=d:
  o=d
else:
  o=m
  m=d

# Find 3rd and 4th small numbers from n,o

if n<=o:
  e=n
  f=o
else:
  e=o
  f=n

print(a,m,e,f)
# Out:
# Enter a number42
# Enter a number100
# Enter a number95
# Enter a number68
# 42 68 95 100
