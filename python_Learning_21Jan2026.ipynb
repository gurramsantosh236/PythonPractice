# %% [markdown]
# <a href="https://colab.research.google.com/github/gurramsantosh236/PythonPractice/blob/main/python_Learning_21Jan2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import random
calulate_number=random.randint(1,10)
attempt=0
print(calulate_number)
print("Guess the number between 1 to 10")
while True or attempt==5:
  try:
    print("Attempt:",attempt+1)
    attempt+=1
    userinput=int(input("Enter your Number:"))
    #userinput=int(input("Enter your Number:"))
    if userinput>calulate_number:
      print("Entered number is greater than guessed number,try again")
    elif userinput<calulate_number:
      print("Entered number is smaller than guessed number,try again")
    else:
      print("Congratulations,You have guessed the correct number")
      break
  except ValueError:
    print("Invalid input.Please enter a valid number.")
# Out:
# 10
# Guess the number between 1 to 10
# Enter your Number:3
# Entered number is smaller than guessed number,try again
# Enter your Number:4
# Entered number is smaller than guessed number,try again
# Enter your Number:4
# Entered number is smaller than guessed number,try again
# Enter your Number:34
# Entered number is greater than guessed number,try again
# Enter your Number:5
# Entered number is smaller than guessed number,try again
# Enter your Number:5
# Entered number is smaller than guessed number,try again
# Enter your Number:21
# Entered number is greater than guessed number,try again
