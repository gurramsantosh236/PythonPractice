# %%
print("Hello World")
# Out:
# Hello World

# %%
lst1=[13,2,3,4,10]
print(lst1*2)
print(*lst1,sep=",")
# Out:
# [13, 2, 3, 4, 10, 13, 2, 3, 4, 10]
# 13,2,3,4,10

# %%
print(max(lst1))
print(min(lst1))
print(sorted(lst1,reverse=True))
print(lst1)
lst1.sort()
print(lst1)
# Out:
# 13
# 2
# [13, 10, 4, 3, 2]
# [2, 3, 4, 10, 13]
# [2, 3, 4, 10, 13]
